# %% [markdown]
# # Translation

# %%
from pathlib import Path
import re

# %%
REPO = Path('../..')
MANUAL = REPO / 'Manual'

# %% [markdown]
# ## Gemini

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=Path('google_api_key.private.txt').read_text())
# genai.configure(api_key='AIzaSyBAsAdiHYQxkv4kYhO94aoK3xq2qbcB5QQ')
# Out:
# 1430 4336
# ..\..\Manual\reference\evaluator\README.md

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-1.0-pro-latest')
MAX_TOKEN = 2048

# %%
page = MANUAL / r'Manual\basic_concepts\the_lister\tabs\README.md'.removeprefix('Manual\\')
content = page.read_text()

async def split_by_max_tokens(s: str) -> list[str]:
    slices = []
    async def append_slice(slice: str):
        tokens = (await model.count_tokens_async(buf)).total_tokens
        print(tokens, len(buf))
        assert tokens < MAX_TOKEN

        slices.append(slice)
    
    buf = ''
    for line in s.splitlines(keepends=True):
        if len(buf) < MAX_TOKEN * 3.5:
            buf += line
        else:
            await append_slice(buf)
            buf = line
    await append_slice(buf)
    
    return slices

slices = await split_by_max_tokens(content)
# Out:
# 1790 7331
# 1409 6021

# %%
outputs = []
for slice in slices:
    if '<table>' in slice:
        prompt = 'Translate the following English text into Chinese, except keyword wrapped by "**", preserving HTML tags: '
    elif 'evaluator' in slice:
        prompt = 'Translate the following English text into Chinese, except code: '
    elif 'label' in slice:
        prompt = 'Translate the following English text into Chinese, where "label" is "标记": '
    else:
        prompt = 'Translate the following English text into Chinese: '
    response = model.generate_content(prompt + slice)
    output = response.text
    print(model.count_tokens(output).total_tokens, len(output))
    outputs.append(output)

# %%
lspace = r'(?:(?<![#-*]) )?'
terminology_fixes = {
    # Lister
    rf'{lspace}Lister ?(?:浏览器)?|列表器|目录查看器': '文件窗口',
    # Default Lister
    r'默认的?(?:文件列表器|列表器?|目录查看器)': '默认文件窗口',
    # file display
    r'文件[显展]示': '文件列表',
    # dual display
    r'双显示|双文件列表': '双栏',
    # location bar
    r'位置栏': '地址栏',
    # (folder) tab
    r'选项卡': '标签页',
    # Preferences
    r'“?首选项”?': '配置',
    # find-as-you-type
    rf'按您输入查找|按键即[查搜]|键入时查找|即时搜[素索]|[随即][打输][随即][找查]|逐字查找|{lspace}FAYT ?|{lspace}Find-As-You-Type ?': '即时查找',
    # view mode
    r'查看模式': '视图',
    # Power mode
    rf'“?强力”?模式|{lspace}\*?Power\*? 模式': '增强模式',
    # Tiles mode
    r'磁贴': '平铺',
    # SmartFavorites
    rf'{lspace}SmartFavorites ?': '智能收藏夹',
    # filter
    r'筛选': '过滤',
    # Evaluator
    rf'{lspace}Evaluator ?|评估器|计算器': '求值器',
    # evaluate
    r'评估': '求值',
    # Explorer
    rf'{lspace}Explorer ?': '资源管理器',
    r'外壳': ' Shell ',
    # archive
    r'(?<!已)(?:存档|归档)': '压缩包',
    # (USB) thumb drive
    r'拇指盘': 'U盘',
    # option
    r'选件': '选项',
    # ad-hoc
    r'即席': '临时',
    # single-click
    r'单机': '单击', 
    # rename
    r'重新命名': '重命名',

    r'\A(?:<h\d>)?\**[#＃]+ ?([^*\r\n<]*)\**(?:</h\d>)?': r'# \1',
    r'！(?=\[[^\]]*\]\(/Manual/)': '!',
    r'\.md': '.zh.md',
}
# TODO: Manual\preferences\preferences_categories\miscellaneous\advanced_options.zh.md

# label
# preferences\preferences_categories\labels
# (?<!文件夹)标签(?!页)

# %%
def process_translation(text: str):
    for regex, term in terminology_fixes.items():
        text = re.sub(regex, term, text)
    return text

result = '\n'.join(outputs)
result = process_translation(result)
page.with_suffix('.zh.md').write_text(result)

# %%
import asyncio

async def process_page(page: Path):
    content = page.read_text()
    command = None
    if page.parent.name == 'internal_commands' and page.name != 'README.md':
        command = re.match(r'\A# (.+)', content).group(1)

    try:
        slices = await split_by_max_tokens(content)
    except AssertionError:
        print('Failed to split content')
        return

    outputs = []
    for slice in slices:
        if command is not None or '<table>' in slice:
            prompt = f'Translate the following English text into Chinese, except keyword wrapped by "**" and{" command" if command is not None else ""} code, preserving HTML tags: '
        elif 'evaluator' in slice:
            prompt = 'Translate the following English text into Chinese, except code: '
        elif 'label' in slice:
            prompt = 'Translate the following English text into Chinese, where "label" is "标记": '
        else:
            prompt = 'Translate the following English text into Chinese: '
        response = await model.generate_content_async(prompt + slice)
        output = response.text
        print((await model.count_tokens_async(output)).total_tokens, len(output))
        outputs.append(output)
    
    def process_translation(text: str):
        for regex, term in terminology_fixes.items():
            text = re.sub(regex, term, text)
        if command is not None:
            text = re.sub(r'\A(?:# .+\n)?', f'# {command}\n', text)
        return text

    result = '\n'.join(outputs)
    result = process_translation(result)
    print(page)
    page.with_suffix('.zh.md').write_text(result)

async def process():
    tasks = []
    # for page in (MANUAL / r'Manual\reference\command_reference\internal_commands'.removeprefix('Manual\\')).glob('**/*.md'):
    for page in MANUAL.glob('**/*.md'):
        if page.name.endswith('.zh.md') or page.with_suffix('.zh.md').exists():
            continue
        # print(page)
        tasks.append(process_page(page))

        if len(tasks) >= 5:
            await asyncio.gather(*tasks)
            tasks = []

    await asyncio.gather(*tasks)

while True:
    try:
        await process()
        break
    except Exception as e:
        print(e)
# Out:
# 87 268
# 229 861
# 420 3401
# 1545 7249
# 2255 7267
# Failed to split content
# 1538 7175
# 1586 7230
# 1635 7190
# 1484 7331
# 1465 7188
# 89 196
# ..\..\Manual\reference\evaluator\swap.md
# 1624 7182
# 1663 7337
# 604 2625
# 274 610
# ..\..\Manual\reference\evaluator\truncate.md
# 400 2894
# ..\..\Manual\reference\evaluator\sysinfo.md
# 1531 4747
# 1534 5678
# 1609 4760
# 509 1096
# 1450 5241
# 1412 4252
# 2048 35559
# 1617 4136
# 572 1253
# ..\..\Manual\reference\command_reference\command_modifier_reference.md
# 149 504
# 92 295
# 218 868
# 113 421
# 1673 5026
# 95 229
# ..\..\Manual\reference\evaluator\ucase.md
# 126 272
# ..\..\Manual\reference\evaluator\typeof.md
# 108 234
# ..\..\Manual\reference\evaluator\val.md
# 217 675
# ..\..\Manual\reference\evaluator\urlencode.md
# 1651 3783
# ..\..\Manual\reference\icon_sets\dpi_aware_icon_sets.md
# 612 2462
# 208 834
# 404 1819
# 514 2057
# 554 2146
# 211 401
# ..\..\Manual\reference\icon_sets\icon_display_names.md
# 353 614
# ..\..\Manual\reference\icon_sets\icon_names.md
# 486 973
# ..\..\Manual\reference\icon_sets\icon_images.md
# 515 1173
# ..\..\Manual\reference\icon_sets\icon_set_xml_definition_file.md
# 597 1254
# ..\..\Manual\reference\icon_sets\icon_categories.md
# 317 1168
# 334 1175
# 419 1707
# 1810 7177
# 1967 7195
# 1852 7207
# 2316 7172
# Failed to split content
# 421 1474
# 287 597
# ..\..\Manual\reference\icon_sets\icon_sizes.md
# 318 764
# ..\..\Manual\reference\icon_sets\README.md
# 425 1137
# ..\..\Manual\reference\icon_sets\localization.md
# 1779 5401
# 1867 5627
# 433 1290
# ..\..\Manual\reference\metadata_keywords\keywords_for_columns.md
# 217 948
# 279 1145
# 194 844
# 212 806
# 184 723
# 195 562
# ..\..\Manual\reference\scripting_reference\scripting_events\onactivatelister.md
# 175 468
# ..\..\Manual\reference\scripting_reference\scripting_events\onactivatetab.md
# 201 549
# ..\..\Manual\reference\scripting_reference\scripting_events\onaboutscript.md
# 207 485
# ..\..\Manual\reference\scripting_reference\README.md
# 270 759
# ..\..\Manual\reference\metadata_keywords\README.md
# 325 1304
# 287 1051
# 294 1044
# 286 1162
# 301 1304
# 264 756
# ..\..\Manual\reference\scripting_reference\scripting_events\onaddcommands.md
# 260 711
# ..\..\Manual\reference\scripting_reference\scripting_events\onafterfolderchange.md
# 270 687
# ..\..\Manual\reference\scripting_reference\scripting_events\onclick.md
# 271 765
# ..\..\Manual\reference\scripting_reference\scripting_events\onaddcolumns.md
# 301 789
# ..\..\Manual\reference\scripting_reference\scripting_events\onbeforefolderchange.md
# 249 977
# 230 938
# 184 732
# 614 2423
# 341 1525
# 173 524
# ..\..\Manual\reference\scripting_reference\scripting_events\ondisplaymodechange.md
# 214 625
# ..\..\Manual\reference\scripting_reference\scripting_events\oncloselister.md
# 233 622
# ..\..\Manual\reference\scripting_reference\scripting_events\onclosetab.md
# 302 836
# ..\..\Manual\reference\scripting_reference\scripting_events\onfileoperationcomplete.md
# 557 1367
# ..\..\Manual\reference\scripting_reference\scripting_events\ondoubleclick.md
# 195 816
# 204 762
# 317 1257
# 492 2006
# 261 1045
# 190 537
# ..\..\Manual\reference\scripting_reference\scripting_events\onfilesystemchange.md
# 197 559
# ..\..\Manual\reference\scripting_reference\scripting_events\onflatviewchange.md
# 240 617
# ..\..\Manual\reference\scripting_reference\scripting_events\ongethelpcontent.md
# 318 792
# ..\..\Manual\reference\scripting_reference\scripting_events\ongetcustomfields.md
# 482 1152
# ..\..\Manual\reference\scripting_reference\scripting_events\ongetcopyqueuename.md
# 422 1669
# 474 1867
# 185 751
# 216 927
# 212 829
# 176 503
# ..\..\Manual\reference\scripting_reference\scripting_events\onlisterresize.md
# 194 559
# ..\..\Manual\reference\scripting_reference\scripting_events\onlisteruichange.md
# 215 577
# ..\..\Manual\reference\scripting_reference\scripting_events\oninitincludefile.md
# 404 937
# ..\..\Manual\reference\scripting_reference\scripting_events\ongetnewname.md
# 445 1136
# ..\..\Manual\reference\scripting_reference\scripting_events\oninit.md
# 215 898
# 192 756
# 334 1401
# 400 1636
# 162 678
# 142 358
# ..\..\Manual\reference\scripting_reference\scripting_events\onscriptconfigchange.md
# 188 492
# ..\..\Manual\reference\scripting_reference\scripting_events\onopentab.md
# 197 543
# ..\..\Manual\reference\scripting_reference\scripting_events\onopenlister.md
# 344 907
# ..\..\Manual\reference\scripting_reference\scripting_events\onscriptcommand.md
# 369 999
# ..\..\Manual\reference\scripting_reference\scripting_events\onscriptcolumn.md
# 324 1244
# 200 814
# 198 768
# 183 723
# 181 713
# 168 457
# ..\..\Manual\reference\scripting_reference\scripting_events\onstartup.md
# 189 518
# ..\..\Manual\reference\scripting_reference\scripting_events\onsourcedestchange.md
# 170 517
# ..\..\Manual\reference\scripting_reference\scripting_events\onstyleselected.md
# 194 556
# ..\..\Manual\reference\scripting_reference\scripting_events\onshutdown.md
# 309 836
# ..\..\Manual\reference\scripting_reference\scripting_events\onscriptfaytcommand.md
# 443 1951
# 210 817
# 155 636
# 247 1061
# 193 739
# 147 462
# ..\..\Manual\reference\scripting_reference\scripting_events\onsystemsettingchange.md
# 173 464
# ..\..\Manual\reference\scripting_reference\scripting_objects\aboutdata.md
# 205 517
# ..\..\Manual\reference\scripting_reference\scripting_events\ontabclick.md
# 245 630
# ..\..\Manual\reference\scripting_reference\scripting_events\onviewerevent.md
# 411 950
# ..\..\Manual\reference\scripting_reference\scripting_events\README.md
# 275 1108
# 215 821
# 303 1140
# 234 889
# 461 1798
# 177 506
# ..\..\Manual\reference\scripting_reference\scripting_objects\addcmddata.md
# 215 613
# ..\..\Manual\reference\scripting_reference\scripting_objects\addcoldata.md
# 275 725
# ..\..\Manual\reference\scripting_reference\scripting_objects\activatelisterdata.md
# 293 737
# ..\..\Manual\reference\scripting_reference\scripting_objects\activatetabdata.md
# 451 1047
# ..\..\Manual\reference\scripting_reference\scripting_objects\afterfolderchangedata.md
# 187 702
# 384 1502
# 485 1875
# 438 1809
# 233 1009
# 189 483
# ..\..\Manual\reference\scripting_reference\scripting_objects\alias.md
# 217 587
# ..\..\Manual\reference\scripting_reference\scripting_objects\audiometa.md
# 408 900
# ..\..\Manual\reference\scripting_reference\scripting_objects\args.md
# 377 915
# ..\..\Manual\reference\scripting_reference\scripting_objects\aliases.md
# 477 1246
# ..\..\Manual\reference\scripting_reference\scripting_objects\audiocoverart.md
# 418 1601
# 119 504
# 289 1124
# 952 4063
# 1604 6167
# 111 318
# ..\..\Manual\reference\scripting_reference\scripting_objects\clickdata.md
# 269 751
# ..\..\Manual\reference\scripting_reference\scripting_objects\closelisterdata.md
# 405 992
# ..\..\Manual\reference\scripting_reference\scripting_objects\beforefolderchangedata.md
# 909 2168
# ..\..\Manual\reference\scripting_reference\scripting_objects\busyindicator.md
# 1520 3412
# ..\..\Manual\reference\scripting_reference\scripting_objects\blob.md
# 220 807
# 509 1959
# 155 628
# 150 616
# 1893 7433
# 1843 7185
# 380 1513
# 123 391
# ..\..\Manual\reference\scripting_reference\scripting_objects\columnvalue.md
# 137 407
# ..\..\Manual\reference\scripting_reference\scripting_objects\configchangedata.md
# 197 514
# ..\..\Manual\reference\scripting_reference\scripting_objects\closetabdata.md
# 490 1254
# ..\..\Manual\reference\scripting_reference\scripting_objects\column.md
# 1679 3846
# 381 1531
# 347 839
# ..\..\Manual\reference\scripting_reference\scripting_objects\command.md
# 361 1464
# 333 1348
# 1893 7252
# 1821 7206
# 1736 7202
# 1928 7316
# 53 202
# 1691 7177
# 181 593
# 1837 7357
# 1845 7217
# 1792 7283
# 1672 7205
# 6 29
# 315 791
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistcolumn.md
# 336 812
# ..\..\Manual\reference\scripting_reference\scripting_objects\customfielddata.md
# 1666 4823
# 1671 3794
# 51 150
# ..\..\Manual\reference\scripting_reference\scripting_objects\date.md
# 150 621
# 1835 4110
# 1689 3784
# 1813 4211
# 173 394
# ..\..\Manual\reference\scripting_reference\scripting_objects\control.md
# 1732 4174
# 1662 3571
# 1603 3834
# 8 13
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialog.md
# 156 682
# 179 705
# 304 1128
# 764 2985
# 938 3616
# 142 393
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialogoption.md
# 164 467
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistgroup.md
# 294 765
# ..\..\Manual\reference\scripting_reference\scripting_objects\displaymodechangedata.md
# 539 1124
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistcolumns.md
# 857 1925
# ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistitem.md
# 135 560
# 101 434
# 793 3053
# 1808 7209
# 1565 5893
# 1699 7341
# 520 1883
# 99 264
# ..\..\Manual\reference\scripting_reference\scripting_objects\dock.md
# 123 365
# ..\..\Manual\reference\scripting_reference\scripting_objects\docmeta.md
# 750 1882
# ..\..\Manual\reference\scripting_reference\scripting_objects\doubleclickdata.md
# 1457 3591
# ..\..\Manual\reference\scripting_reference\scripting_objects\dopusfactory.md
# 1809 5166
# 1580 4213
# 517 1224
# ..\..\Manual\reference\scripting_reference\scripting_objects\dopus.md
# 347 1203
# 138 571
# 416 1555
# 526 2062
# 1048 4202
# 127 381
# ..\..\Manual\reference\scripting_reference\scripting_objects\exemeta.md
# 322 816
# ..\..\Manual\reference\scripting_reference\scripting_objects\dpi.md
# 408 1001
# ..\..\Manual\reference\scripting_reference\scripting_objects\drive.md
# 525 1296
# ..\..\Manual\reference\scripting_reference\scripting_objects\favorite.md
# 1008 2252
# ..\..\Manual\reference\scripting_reference\scripting_objects\favorites.md
# 409 1680
# 1056 4358
# 574 2352
# 1895 7233
# 1491 5689
# 66 286
# 362 882
# ..\..\Manual\reference\scripting_reference\scripting_objects\filegroup.md
# 529 1392
# ..\..\Manual\reference\scripting_reference\scripting_objects\fileoperationcompletedata.md
# 939 2211
# ..\..\Manual\reference\scripting_reference\scripting_objects\fileattr.md
# 1387 3217
# ..\..\Manual\reference\scripting_reference\scripting_objects\filesize.md
# 1748 3703
# 47 116
# ..\..\Manual\reference\scripting_reference\scripting_objects\file.md
# 164 647
# 522 2114
# 197 816
# 531 2119
# 599 2368
# 151 417
# ..\..\Manual\reference\scripting_reference\scripting_objects\filesystemchangedata.md
# 177 521
# ..\..\Manual\reference\scripting_reference\scripting_objects\filterparseerror.md
# 494 1195
# ..\..\Manual\reference\scripting_reference\scripting_objects\filetypegroup.md
# 541 1322
# ..\..\Manual\reference\scripting_reference\scripting_objects\filetypegroups.md
# 583 1516
# ..\..\Manual\reference\scripting_reference\scripting_objects\filter.md
# 295 1075
# 438 1715
# 518 1928
# 1821 7201
# 1715 7339
# 136 564
# 1990 7242
# 1386 7196
# 1379 7184
# 6 29
# 287 737
# ..\..\Manual\reference\scripting_reference\scripting_objects\flatviewchangedata.md
# 407 1041
# ..\..\Manual\reference\scripting_reference\scripting_objects\folderenum.md
# 482 1300
# ..\..\Manual\reference\scripting_reference\scripting_objects\fontmeta.md
# 1619 4515
# 1831 4588
# 119 299
# ..\..\Manual\reference\scripting_reference\scripting_objects\format.md
# 1897 4302
# 1299 4513
# 1382 4778
# 8 13
# ..\..\Manual\reference\scripting_reference\scripting_objects\fsutil.md
# 550 1996
# 483 1908
# 913 3643
# 616 2420
# 751 2871
# 471 1125
# ..\..\Manual\reference\scripting_reference\scripting_objects\getcustomfielddata.md
# 520 1260
# ..\..\Manual\reference\scripting_reference\scripting_objects\getcopyqueuenamedata.md
# 582 1366
# ..\..\Manual\reference\scripting_reference\scripting_objects\gethelpcontentdata.md
# 700 1769
# ..\..\Manual\reference\scripting_reference\scripting_objects\getnewnamedata.md
# 825 2107
# ..\..\Manual\reference\scripting_reference\scripting_objects\func.md
# 290 1251
# 266 1044
# 128 521
# 462 1878
# 135 566
# 129 358
# ..\..\Manual\reference\scripting_reference\scripting_objects\imagemeta.md
# 119 361
# ..\..\Manual\reference\scripting_reference\scripting_objects\highlightedcolumns.md
# 250 702
# ..\..\Manual\reference\scripting_reference\scripting_objects\image.md
# 299 792
# ..\..\Manual\reference\scripting_reference\scripting_objects\globalfilters.md
# 427 1051
# ..\..\Manual\reference\scripting_reference\scripting_objects\includefileinitdata.md
# 410 1676
# 236 936
# 557 2275
# 1806 7206
# 1834 7247
# 1786 7462
# 685 2933
# 493 2085
# 257 646
# ..\..\Manual\reference\scripting_reference\scripting_objects\listerresizedata.md
# 400 1006
# ..\..\Manual\reference\scripting_reference\scripting_objects\items.md
# 521 1312
# ..\..\Manual\reference\scripting_reference\scripting_objects\listers.md
# 1610 4286
# 1747 4635
# 661 1698
# ..\..\Manual\reference\scripting_reference\scripting_objects\lister.md
# 1074 2867
# 441 930
# ..\..\Manual\reference\scripting_reference\scripting_objects\item.md
# 318 1216
# 984 3424
# 311 1209
# 1090 4349
# 1400 7212
# 951 5386
# 292 777
# ..\..\Manual\reference\scripting_reference\scripting_objects\openlisterdata.md
# 336 722
# ..\..\Manual\reference\scripting_reference\scripting_objects\listeruichangedata.md
# 948 2490
# ..\..\Manual\reference\scripting_reference\scripting_objects\map.md
# 1056 2284
# ..\..\Manual\reference\scripting_reference\scripting_objects\metadata.md
# 1350 4814
# 926 3931
# ..\..\Manual\reference\scripting_reference\scripting_objects\msg.md
# 467 1807
# 222 818
# 615 2556
# 1874 7344
# 1827 7329
# 6 29
# 1062 4068
# 217 524
# ..\..\Manual\reference\scripting_reference\scripting_objects\opentabdata.md
# 461 1227
# ..\..\Manual\reference\scripting_reference\scripting_objects\pairedfolder.md
# 568 1540
# ..\..\Manual\reference\scripting_reference\scripting_objects\othermeta.md
# 1750 3795
# 1798 4252
# 8 13
# ..\..\Manual\reference\scripting_reference\scripting_objects\path.md
# 1018 2446
# ..\..\Manual\reference\scripting_reference\scripting_objects\progress.md
# 589 2232
# 339 1484
# 548 2161
# 1841 7271
# 1191 4712
# 1905 7181
# 1920 7313
# 1875 7208
# 1932 7328
# 620 2555
# 325 748
# ..\..\Manual\reference\scripting_reference\scripting_objects\results.md
# 474 994
# ..\..\Manual\reference\scripting_reference\scripting_objects\quickfilter.md
# 540 1210
# ..\..\Manual\reference\scripting_reference\scripting_objects\rect.md
# 1089 2650
# ..\..\Manual\reference\scripting_reference\scripting_objects\script.md
# 1745 4217
# 1849 5303
# 1805 5131
# 1787 4881
# 1847 5297
# 580 1614
# ..\..\Manual\reference\scripting_reference\scripting_objects\README.md
# 144 554
# 1804 7489
# 1782 7242
# 331 1314
# 974 3887
# 305 1246
# 1431 7454
# 59 256
# 140 359
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolorpair.md
# 298 776
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcommanddata.md
# 919 2306
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcommand.md
# 1690 3893
# 1669 3753
# 109 263
# 96 211
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolumndata.md
# 51 118
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolumn.md
# 440 1894
# 1003 3960
# 525 1998
# 1599 6599
# 293 1233
# 273 775
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptstrings.md
# 404 937
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptconfig.md
# 482 1227
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptfaytcommanddata.md
# 932 2216
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptfaytcommand.md
# 1529 3832
# ..\..\Manual\reference\scripting_reference\scripting_objects\scriptinitdata.md
# 426 1756
# 207 848
# 231 902
# 385 1554
# 256 1031
# 191 554
# ..\..\Manual\reference\scripting_reference\scripting_objects\smartfavorite.md
# 225 595
# ..\..\Manual\reference\scripting_reference\scripting_objects\shutdowndata.md
# 241 760
# ..\..\Manual\reference\scripting_reference\scripting_objects\smartfavorites.md
# 354 846
# ..\..\Manual\reference\scripting_reference\scripting_objects\sortorder.md
# 379 989
# ..\..\Manual\reference\scripting_reference\scripting_objects\shellproperty.md
# 75 276
# 559 2123
# 299 1116
# 265 1015
# 1884 7221
# 36 164
# 74 183
# ..\..\Manual\reference\scripting_reference\scripting_objects\startupdata.md
# 257 689
# ..\..\Manual\reference\scripting_reference\scripting_objects\styleselecteddata.md
# 291 743
# ..\..\Manual\reference\scripting_reference\scripting_objects\sourcedestdata.md
# 540 1501
# ..\..\Manual\reference\scripting_reference\scripting_objects\stringset.md
# 1793 4914
# 28 47
# ..\..\Manual\reference\scripting_reference\scripting_objects\stringtools.md
# 494 3766
# 1281 5136
# 226 840
# 1806 7168
# 1213 4726
# 1053 4165
# 220 545
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabclickdata.md
# 477 3150
# ..\..\Manual\reference\scripting_reference\scripting_objects\systemsettingchangedata.md
# 1189 3050
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabgroup.md
# 1335 2902
# ..\..\Manual\reference\scripting_reference\scripting_objects\sysinfo.md
# 1761 4220
# 993 2276
# ..\..\Manual\reference\scripting_reference\scripting_objects\tab.md
# 474 1795
# 811 3112
# 756 2707
# 1256 4936
# 562 2260
# 468 1209
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabgrouptabentry.md
# 538 1268
# ..\..\Manual\reference\scripting_reference\scripting_objects\toolbar.md
# 739 1859
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabgrouptablist.md
# 784 2059
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabgroups.md
# 1189 3354
# ..\..\Manual\reference\scripting_reference\scripting_objects\tabstats.md
# 346 1377
# 876 3188
# 471 1903
# 1237 4756
# 1393 5563
# 325 799
# ..\..\Manual\reference\scripting_reference\scripting_objects\toolbars.md
# 443 1095
# ..\..\Manual\reference\scripting_reference\scripting_objects\var.md
# 861 2220
# ..\..\Manual\reference\scripting_reference\scripting_objects\unorderedset.md
# 1188 3019
# ..\..\Manual\reference\scripting_reference\scripting_objects\vars.md
# 1356 2961
# ..\..\Manual\reference\scripting_reference\scripting_objects\vector.md
# 412 1630
# 135 562
# 1612 7224
# 502 2020
# 170 675
# 416 1719
# 125 360
# ..\..\Manual\reference\scripting_reference\scripting_objects\videometa.md
# 174 444
# ..\..\Manual\reference\scripting_reference\scripting_objects\viewers.md
# 389 998
# ..\..\Manual\reference\scripting_reference\scripting_objects\version.md
# 485 1159
# ..\..\Manual\reference\scripting_reference\scripting_objects\viewereventdata.md
# 1536 4731
# 406 938
# ..\..\Manual\reference\scripting_reference\scripting_objects\viewer.md
# 538 1859
# 624 2590
# 1936 7217
# 822 2936
# 2060 7188
# Failed to split content
# 1196 4173
# 591 1607
# ..\..\Manual\reference\scripting_reference\scripting_objects\winver.md
# 599 1425
# ..\..\Manual\reference\scripting_reference\scripting_objects\wild.md
# 794 1415
# ..\..\Manual\reference\status_bar_codes\codes_for_disk_space.md
# 1861 3299
# 66 107
# ..\..\Manual\reference\status_bar_codes\bar_graphs_and_percentages.md
# 605 2278
# 126 560
# 902 3559
# 993 3883
# 1985 7460
# 1918 7226
# 6 29
# 115 276
# ..\..\Manual\reference\status_bar_codes\codes_for_music_and_video_duration.md
# 574 1178
# ..\..\Manual\reference\status_bar_codes\codes_for_graphical_elements.md
# 883 1571
# ..\..\Manual\reference\status_bar_codes\hiding_sections_on_the_status_bar.md
# 955 1781
# ..\..\Manual\reference\status_bar_codes\padding_sections_on_the_status_bar.md
# 1878 4060
# 1883 3861
# 8 13
# ..\..\Manual\reference\status_bar_codes\other_codes.md
# 413 1517
# 214 923
# 96 301
# 1448 5263
# 1922 7265
# 592 2123
# 103 213
# ..\..\Manual\release_history\opus132.md
# 212 541
# ..\..\Manual\reference\wildcard_reference\README.md
# 399 965
# ..\..\Manual\reference\status_bar_codes\README.md
# 1444 2920
# ..\..\Manual\reference\wildcard_reference\pattern_matching_syntax.md
# 1901 3935
# 594 1411
# ..\..\Manual\reference\wildcard_reference\regular_expression_syntax.md
# 2021 7272
# 168 521
# 605 2271
# 397 1739
# 915 3339
# 2069 7173
# Failed to split content
# 163 373
# ..\..\Manual\release_history\README.md
# 405 1335
# ..\..\Manual\release_history\opus13\page2.md
# 596 1654
# ..\..\Manual\release_history\opus13\page1.md
# 918 2362
# ..\..\Manual\release_history\opus13\page3.md
# 1252 4274
# 674 2579
# 405 1256
# 807 3159
# 125 559
# 131 324
# ..\..\Manual\release_history\opus13_detailed\aliases.md
# 417 840
# ..\..\Manual\release_history\opus13\README.md
# 684 1793
# ..\..\Manual\release_history\opus13\page5.md
# 833 2241
# ..\..\Manual\release_history\opus13\page6.md
# 1260 3185
# ..\..\Manual\release_history\opus13\page4.md
# 404 1738
# 232 1009
# 1656 7205
# 1433 6197
# 1488 6411
# 429 1645
# 241 511
# ..\..\Manual\release_history\opus13_detailed\cloud_storage.md
# 377 816
# ..\..\Manual\release_history\opus13_detailed\archives.md
# 1399 2380
# ..\..\Manual\release_history\opus13_detailed\customize.md
# 1462 2579
# ..\..\Manual\release_history\opus13_detailed\dark_mode.md
# 1643 2958
# 469 954
# ..\..\Manual\release_history\opus13_detailed\columns.md
# 340 1568
# 505 2049
# 1645 6874
# 383 1683
# 972 3907
# 315 645
# ..\..\Manual\release_history\opus13_detailed\evaluator.md
# 375 874
# ..\..\Manual\release_history\opus13_detailed\everything.md
# 512 1023
# ..\..\Manual\release_history\opus13_detailed\duplicates.md
# 976 1879
# ..\..\Manual\release_history\opus13_detailed\fayt.md
# 1697 2997
# ..\..\Manual\release_history\opus13_detailed\default_toolbars.md
# 1625 7217
# 214 914
# 667 2733
# 1597 7301
# 1765 7258
# 77 323
# 819 3393
# 848 3141
# 231 467
# ..\..\Manual\release_history\opus13_detailed\filter_bar.md
# 650 1261
# ..\..\Manual\release_history\opus13_detailed\file_types.md
# 1540 2768
# 1518 2545
# 71 223
# ..\..\Manual\release_history\opus13_detailed\file_copying.md
# 1786 3547
# 790 1501
# ..\..\Manual\release_history\opus13_detailed\file_display.md
# 839 2075
# ..\..\Manual\release_history\opus13_detailed\find.md
# 1414 6224
# 545 2453
# 1521 6251
# 1334 5697
# 381 1574
# 393 783
# ..\..\Manual\release_history\opus13_detailed\image_convert.md
# 534 1079
# ..\..\Manual\release_history\opus13_detailed\folder_sizes.md
# 1315 2292
# ..\..\Manual\release_history\opus13_detailed\folder_tree.md
# 1512 2739
# ..\..\Manual\release_history\opus13_detailed\folder_tabs.md
# 1410 2590
# ..\..\Manual\release_history\opus13_detailed\folder_formats.md
# 317 1426
# 157 665
# 686 2952
# 1087 4704
# 1938 7225
# 1792 7202
# 1099 4176
# 164 402
# ..\..\Manual\release_history\opus13_detailed\lister_defaults.md
# 315 649
# ..\..\Manual\release_history\opus13_detailed\labels.md
# 655 1261
# ..\..\Manual\release_history\opus13_detailed\location_bar.md
# 1121 2047
# ..\..\Manual\release_history\opus13_detailed\metadata.md
# 1846 3815
# 1766 4015
# 1058 2224
# ..\..\Manual\release_history\opus13_detailed\misc_commands.md
# 1110 4824
# 638 2846
# 156 658
# 1776 7227
# 642 2975
# 1383 5740
# 167 376
# ..\..\Manual\release_history\opus13_detailed\other_util.md
# 641 1303
# ..\..\Manual\release_history\opus13_detailed\misc_fixes.md
# 677 1227
# ..\..\Manual\release_history\opus13_detailed\preferences.md
# 1114 2165
# ..\..\Manual\release_history\opus13_detailed\misc_features.md
# 1751 4068
# 1411 3229
# ..\..\Manual\release_history\opus13_detailed\misc_scripting.md
# 250 1015
# 1244 3624
# 413 1873
# 1908 7376
# 931 4015
# 245 856
# 261 600
# ..\..\Manual\release_history\opus13_detailed\print_folder.md
# 400 869
# ..\..\Manual\release_history\opus13_detailed\removed.md
# 903 1760
# ..\..\Manual\release_history\opus13_detailed\script_ide.md
# 1252 3139
# ..\..\Manual\release_history\opus13_detailed\README.md
# 1942 3499
# 242 733
# ..\..\Manual\release_history\opus13_detailed\rename.md
# 484 2059
# 125 534
# 316 1434
# 270 1088
# 804 3363
# 122 324
# ..\..\Manual\release_history\opus13_detailed\setattr.md
# 268 568
# ..\..\Manual\release_history\opus13_detailed\split_join.md
# 327 700
# ..\..\Manual\release_history\opus13_detailed\shell_extensions.md
# 465 1080
# ..\..\Manual\release_history\opus13_detailed\search_field.md
# 761 1326
# ..\..\Manual\release_history\opus13_detailed\status_bar.md
# 334 1362
# 231 1067
# 1297 5736
# 467 2062
# 1715 7160
# 243 534
# ..\..\Manual\release_history\opus13_detailed\ui_spacing.md
# 359 760
# ..\..\Manual\release_history\opus13_detailed\synchronize.md
# 466 1043
# ..\..\Manual\release_history\opus13_detailed\virtual_desktops.md
# 1381 2312
# ..\..\Manual\release_history\opus13_detailed\thumbnails.md
# 1802 3462
# ..\..\Manual\release_history\opus13_detailed\viewer.md
# 911 3862
# 8 23
# 556 2351
# 1059 4034
# 371 1329
# 6 12
# ..\..\Manual\scripting\script_log.md
# 348 948
# ..\..\Manual\scripting\example_scripts\adding_a_new_column_from_shell_properties.md
# 522 1127
# ..\..\Manual\scripting\script_functions.md
# 878 1981
# ..\..\Manual\scripting\README.md
# 1025 2649
# ..\..\Manual\scripting\example_scripts\adding_a_new_column.md
# 425 1585
# 12 37
# 410 1412
# 1514 5629
# 846 3294
# 12 22
# ..\..\Manual\scripting\example_scripts\extending_the_fayt.md
# 391 958
# ..\..\Manual\scripting\example_scripts\README.md
# 415 922
# ..\..\Manual\scripting\example_scripts\example_rename_script.md
# 806 2292
# ..\..\Manual\scripting\example_scripts\responding_to_events.md
# 1455 3822
# ..\..\Manual\scripting\example_scripts\adding_a_new_internal_command.md
# 1617 5023
# 824 3059
# 1217 4108
# 1252 5158
# 1125 4447
# 807 2124
# ..\..\Manual\scripting\example_scripts\simple_script_function.md
# 1072 2529
# ..\..\Manual\scripting\rename_scripts\README.md
# 1171 2788
# ..\..\Manual\scripting\example_scripts\simple_dialogs_and_popup_menus.md
# 1247 3485
# ..\..\Manual\scripting\rename_scripts\custom_fields_in_the_rename_dialog.md
# 1594 4165
# ..\..\Manual\scripting\example_scripts\script_dialog_example.md
# 449 1919
# 344 1514
# 579 2386
# 532 2318
# 767 3275
# 310 601
# ..\..\Manual\scripting\script_add-ins\modules.md
# 416 1063
# ..\..\Manual\scripting\resources\README.md
# 509 1007
# ..\..\Manual\scripting\script_add-ins\include_files.md
# 539 1346
# ..\..\Manual\scripting\resources\string_resources.md
# 727 1455
# ..\..\Manual\scripting\script_add-ins\README.md
# 299 1183
# 9 35
# 454 1828
# 1476 5349
# 954 3581
# 9 14
# ..\..\Manual\scripting\script_add-ins\script_installer_file.md
# 276 602
# ..\..\Manual\scripting\script_dialogs\creating_script_dialogs.md
# 442 987
# ..\..\Manual\scripting\script_add-ins\script_package.md
# 909 2446
# ..\..\Manual\scripting\script_dialogs\reading_dialog_control_values.md
# 1524 3455
# ..\..\Manual\scripting\script_dialogs\interacting_with_dialog_controls.md
# 299 1127
# 399 1707
# 1266 4769
# 792 2950
# 300 1287
# 272 673
# ..\..\Manual\scripting\script_dialogs\README.md
# 270 484
# ..\..\Manual\scripting\script_editor\assets.md
# 342 765
# ..\..\Manual\scripting\script_dialogs\the_dialog_message_loop\README.md
# 757 2056
# ..\..\Manual\scripting\script_dialogs\the_dialog_message_loop\simple_dialogs.md
# 1206 3291
# ..\..\Manual\scripting\script_dialogs\the_dialog_message_loop\detached_dialogs.md
# 337 1288
# 288 1247
# 8 24
# 312 1303
# 399 1653
# 8 13
# ..\..\Manual\scripting\script_editor\editors\code_editor.md
# 312 623
# ..\..\Manual\scripting\script_editor\editors\README.md
# 334 756
# ..\..\Manual\scripting\script_editor\README.md
# 282 543
# ..\..\Manual\scripting\script_editor\snippets.md
# 377 888
# ..\..\Manual\scripting\script_editor\editors\string_editor.md
# 560 2091
# 283 1197
# 309 1355
# 421 1443
# 285 1339
# 241 403
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_mnemonics.md
# 259 446
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\language_overlays.md
# 310 507
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_tab_order.md
# 448 838
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_editor_commands.md
# 537 1051
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\adding_dialog_controls.md
# 427 1616
# 291 1361
# 193 905
# 665 2918
# 129 517
# 133 216
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\check_box_properties.md
# 172 317
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\button_properties.md
# 268 462
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\sizing_and_positioning_dialog_controls.md
# 422 1101
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\README.md
# 652 1149
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\using_the_layout_commands.md
# 257 1111
# 721 3143
# 102 462
# 403 1787
# 365 1504
# 95 147
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\group_box_properties.md
# 225 379
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\combo_box_properties.md
# 322 542
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\edit_control_properties.md
# 383 715
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\dialog_properties.md
# 680 1146
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\common_dialog_properties.md
# 173 758
# 70 290
# 97 460
# 557 2069
# 625 2506
# 69 110
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\markup_text_properties.md
# 94 148
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\radio_button_properties.md
# 178 328
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\list_box_properties.md
# 552 1646
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\README.md
# 609 1049
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\list_view_properties.md
# 609 2738
# 114 473
# 501 2209
# 594 2605
# 711 2976
# 108 187
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\tab_control_properties.md
# 486 903
# ..\..\Manual\scripting\script_management\installer.md
# 577 1133
# ..\..\Manual\scripting\script_management\new_script.md
# 589 955
# ..\..\Manual\scripting\script_editor\editors\dialog_editor\dialog_control_properties\static_text_properties.md
# 664 1302
# ..\..\Manual\scripting\script_management\README.md

# %%
chat = model.start_chat(history=[])
response = chat.send_message(f'''According to the terminology table, translate the English text into Chinese:
Terminology:
English | Chinese
--- | ---
Lister | 文件窗口
File display | 文件列表
Find-as-you-type | 即时查找

English text: {q_text}
Chinese:''')
print(response.text)

# %%
print(model.generate_content(f'''English-to-Chinese terminology:
English | Chinese
--- | ---
Lister | 文件窗口
File display | 文件列表
Find-as-you-type | 即时查找

According to the above terminology table, translate the following English text into Chinese: {q_text}''').text)

# %%
print(model.generate_content(f'''According to the terminology table, translate the English text into Chinese:
Terminology:
English | Chinese
--- | ---
Lister | 文件窗口
File display | 文件列表
Find-as-you-type | 即时查找

English text: {q_text}
Chinese:''').text)

# %%
print(model.generate_content(
f'''This is an English to Chinese translation, please provide
the Chinese translation for these sentences:
English: Directory Opus has Lister, file display and find-as-you-type features. Chinese: Directory Opus 拥有文件窗口、文件列表和即时查找功能。
Please provide the translation for the following sentence.
Do not provide any explanations or text apart from the
translation.
English: {q_text}
Chinese: ''').text)

# %% [markdown]
# ### SUMMARY

# %%
SUMMARY = MANUAL / 'SUMMARY.md'

def repl_title(m: re.Match[str]) -> str:
    page = MANUAL / m.group(2).removeprefix('/Manual/')
    zh_page = page.with_suffix('.zh.md')
    try:
        zh_m = re.match(r'\A# (.+)', zh_page.read_text())
    except FileNotFoundError:
        print('FileNotFoundError', zh_page)
        return m.group(0)
    if zh_m is not None:
        title = zh_m.group(1)
    else:
        title = m.group(1)
        print('No title', page)
    return f'[{title}]({m.group(2).replace(".md", ".zh.md")})'

zh_toc = re.sub(r'\[([^\]]+)\]\(([^\)]+)\)', repl_title, SUMMARY.read_text())
SUMMARY.with_suffix('.zh.md').write_text(zh_toc)


SUMMARY = (REPO / 'SUMMARY.md')
sum = SUMMARY.read_text('utf-8')
sum = re.sub('## 官方手册\n[\S\s]*?(?=## Manual)', '## 官方手册\n' + zh_toc + '\n', sum)
SUMMARY.write_text(sum, encoding='utf-8')
# Out:
# FileNotFoundError ..\..\Manual\file_operations\copying_moving_and_deleting_files\README\deleting_files\README.zh.md
# No title ..\..\Manual\ftp\ftp_address_book\display_page.md
# No title ..\..\Manual\preferences\preferences_categories\viewer\standalone_viewer\options.md
# No title ..\..\Manual\customize\the_customize_dialog\user_commands.md
# No title ..\..\Manual\customize\creating_your_own_buttons\editing_the_toolbar\README.md
# No title ..\..\Manual\customize\creating_your_own_buttons\editing_the_toolbar\field_buttons\README.md
# No title ..\..\Manual\file_types\filetype_editor\actions.md
# No title ..\..\Manual\file_types\filetype_editor\info_tip.md
# No title ..\..\Manual\scripting\rename_scripts\custom_fields_in_the_rename_dialog.md
# No title ..\..\Manual\scripting\script_management\README.md
# No title ..\..\Manual\scripting\script_editor\editors\dialog_editor\adding_dialog_controls.md
# No title ..\..\Manual\evaluator\applicable_contexts\README.md
# No title ..\..\Manual\evaluator\applicable_contexts\functions\tooltips.md
# No title ..\..\Manual\evaluator\applicable_contexts\functions\dynamic_state.md
# No title ..\..\Manual\evaluator\applicable_contexts\functions\conditional_behavior.md
# No title ..\..\Manual\evaluator\examples.md
# FileNotFoundError ..\..\Manual\reference\status_bar_codes\codes_for_file_and_folder_counts.zh.md
# FileNotFoundError ..\..\Manual\reference\command_reference\internal_commands\favorites.zh.md
# FileNotFoundError ..\..\Manual\reference\command_reference\internal_commands\find.zh.md
# FileNotFoundError ..\..\Manual\reference\command_reference\internal_commands\properties.zh.md
# No title ..\..\Manual\reference\command_reference\external_control_codes\codes_for_clipboard_and_variables.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\activatetabdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\addcmddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\addcoldata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\afterfolderchangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\audiocoverart.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\audiometa.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\beforefolderchangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\blob.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\busyindicator.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\closelisterdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\closetabdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\columnvalue.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\command.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\configchangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\customfielddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialog.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistcolumn.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistcolumns.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistgroup.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialoglistitem.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dialogoption.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\displaymodechangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\docmeta.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\dopusfactory.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\doubleclickdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\drive.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\exemeta.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\file.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\fileattr.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filegroup.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\fileoperationcompletedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filesize.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filesystemchangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filetypegroup.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filetypegroups.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\filterparseerror.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\folderenum.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\fontmeta.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\format.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\fsutil.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\getcopyqueuenamedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\getcustomfielddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\getnewnamedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\highlightedcolumns.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\imagemeta.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\includefileinitdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\item.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\lister.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\listerresizedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\listeruichangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\msg.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\opentabdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\othermeta.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\pairedfolder.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\path.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\rect.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolorpair.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolumn.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcolumndata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcommand.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptcommanddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptfaytcommand.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptfaytcommanddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptconfig.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptinitdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\scriptstrings.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\shellproperty.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\sortorder.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\sourcedestdata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\stringset.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\stringtools.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\styleselecteddata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\sysinfo.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\systemsettingchangedata.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\tab.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\tabgrouptabentry.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\tabgrouptablist.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\unorderedset.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\vector.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\videometa.md
# No title ..\..\Manual\reference\scripting_reference\scripting_objects\winver.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onaboutscript.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onactivatelister.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onactivatetab.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onaddcolumns.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onaddcommands.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onafterfolderchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onbeforefolderchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onclick.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\oncloselister.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onclosetab.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ondisplaymodechange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ondoubleclick.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onfilesystemchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onfileoperationcomplete.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onflatviewchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ongetcopyqueuename.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ongetcustomfields.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ongetnewname.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\oninit.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\oninitincludefile.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onlisterresize.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onlisteruichange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onopenlister.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onopentab.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onscriptcolumn.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onscriptcommand.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onscriptconfigchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onscriptfaytcommand.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onshutdown.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onsourcedestchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onstartup.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onstyleselected.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onsystemsettingchange.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\ontabclick.md
# No title ..\..\Manual\reference\scripting_reference\scripting_events\onviewerevent.md
# No title ..\..\Manual\reference\evaluator\abortfunc.md
# No title ..\..\Manual\reference\evaluator\abs.md
# No title ..\..\Manual\reference\evaluator\age.md
# No title ..\..\Manual\reference\evaluator\arg.md
# No title ..\..\Manual\reference\evaluator\as.md
# No title ..\..\Manual\reference\evaluator\asc.md
# No title ..\..\Manual\reference\evaluator\atan.md
# No title ..\..\Manual\reference\evaluator\capitalize.md
# No title ..\..\Manual\reference\evaluator\cbrt.md
# No title ..\..\Manual\reference\evaluator\ceil.md
# No title ..\..\Manual\reference\evaluator\chr.md
# No title ..\..\Manual\reference\evaluator\cos.md
# No title ..\..\Manual\reference\evaluator\clip.md
# No title ..\..\Manual\reference\evaluator\clipformat.md
# No title ..\..\Manual\reference\evaluator\count.md
# No title ..\..\Manual\reference\evaluator\datediff.md
# No title ..\..\Manual\reference\evaluator\datepart.md
# No title ..\..\Manual\reference\evaluator\degtorad.md
# No title ..\..\Manual\reference\evaluator\displayname.md
# No title ..\..\Manual\reference\evaluator\elapsed.md
# No title ..\..\Manual\reference\evaluator\exists.md
# No title ..\..\Manual\reference\evaluator\filecount.md
# No title ..\..\Manual\reference\evaluator\fileext.md
# No title ..\..\Manual\reference\evaluator\filepart.md
# No title ..\..\Manual\reference\evaluator\floor.md
# No title ..\..\Manual\reference\evaluator\format.md
# No title ..\..\Manual\reference\evaluator\hypot.md
# No title ..\..\Manual\reference\evaluator\instr.md
# No title ..\..\Manual\reference\evaluator\isalpha.md
# No title ..\..\Manual\reference\evaluator\ischecked.md
# No title ..\..\Manual\reference\evaluator\isdigit.md
# No title ..\..\Manual\reference\evaluator\isenabled.md
# No title ..\..\Manual\reference\evaluator\islower.md
# No title ..\..\Manual\reference\evaluator\isparent.md
# No title ..\..\Manual\reference\evaluator\ispath.md
# No title ..\..\Manual\reference\evaluator\ispunct.md
# No title ..\..\Manual\reference\evaluator\isselected.md
# No title ..\..\Manual\reference\evaluator\isset.md
# No title ..\..\Manual\reference\evaluator\isspace.md
# No title ..\..\Manual\reference\evaluator\isupper.md
# No title ..\..\Manual\reference\evaluator\keydown.md
# No title ..\..\Manual\reference\evaluator\languagestr.md
# No title ..\..\Manual\reference\evaluator\lcase.md
# No title ..\..\Manual\reference\evaluator\left.md
# No title ..\..\Manual\reference\evaluator\len.md
# No title ..\..\Manual\reference\evaluator\makelegal.md
# No title ..\..\Manual\reference\evaluator\match.md
# No title ..\..\Manual\reference\evaluator\max.md
# No title ..\..\Manual\reference\evaluator\mid.md
# No title ..\..\Manual\reference\evaluator\min.md
# No title ..\..\Manual\reference\evaluator\now.md
# No title ..\..\Manual\reference\evaluator\output.md
# No title ..\..\Manual\reference\evaluator\parent.md
# No title ..\..\Manual\reference\evaluator\pathtype.md
# No title ..\..\Manual\reference\evaluator\pow.md
# No title ..\..\Manual\reference\evaluator\radtodeg.md
# No title ..\..\Manual\reference\evaluator\regex.md
# No title ..\..\Manual\reference\evaluator\regexs.md
# No title ..\..\Manual\reference\evaluator\replace.md
# No title ..\..\Manual\reference\evaluator\resolve.md
# No title ..\..\Manual\reference\evaluator\reverse.md
# No title ..\..\Manual\reference\evaluator\right.md
# No title ..\..\Manual\reference\evaluator\root.md
# No title ..\..\Manual\reference\evaluator\round.md
# No title ..\..\Manual\reference\evaluator\running.md
# No title ..\..\Manual\reference\evaluator\select.md
# No title ..\..\Manual\reference\evaluator\sin.md
# No title ..\..\Manual\reference\evaluator\space.md
# No title ..\..\Manual\reference\evaluator\stem.md
# No title ..\..\Manual\reference\evaluator\strcmp.md
# No title ..\..\Manual\reference\evaluator\string.md
# No title ..\..\Manual\reference\evaluator\sqrt.md
# No title ..\..\Manual\reference\evaluator\swap.md
# No title ..\..\Manual\reference\evaluator\sysinfo.md
# No title ..\..\Manual\reference\evaluator\tan.md
# No title ..\..\Manual\reference\evaluator\trim.md
# No title ..\..\Manual\reference\evaluator\truncate.md
# No title ..\..\Manual\reference\evaluator\typeof.md
# No title ..\..\Manual\reference\evaluator\ucase.md
# No title ..\..\Manual\reference\evaluator\urlencode.md
# No title ..\..\Manual\reference\evaluator\val.md
# FileNotFoundError ..\..\Manual\reference\metadata_keywords\keywords_for_setattr_meta.zh.md
# No title ..\..\Manual\reference\icon_sets\dpi_aware_icon_sets.md
# No title ..\..\Manual\release_history\opus13\page1.md
# No title ..\..\Manual\release_history\opus13\page2.md
# No title ..\..\Manual\release_history\opus13\page3.md
# No title ..\..\Manual\release_history\opus13\page4.md
# No title ..\..\Manual\release_history\opus13\page5.md
# No title ..\..\Manual\release_history\opus13\page6.md
# FileNotFoundError ..\..\Manual\release_history\opus13_upgradetips.zh.md
# 151387

# %% [markdown]
# ## Translators

# %%
# translators ~= 5.8
import translators as ts

_ = ts.preaccelerate_and_speedtest()

# %%
# Bing Chat: good
# Baidu: good, but bad at Markdown
# qqTranSmart: not good, and not good at Markdown
# Google: bad

q_text = '''# Argument Types

The following qualifiers are used in the internal command templates to indicate the type of each argument. Remember that you **never** type the qualifiers when using arguments - they are merely a clue as to the argument type.

| Qualifier | Type | Description |
| --- | --- | --- |
| /S | Switch | Indicates a switch argument (a Boolean option that can either be on or off). |
| /K | Keyword | Indicates a value argument (a value must be provided following the argument keyword). |
| /O | Optional | Indicates an optional argument (can be used either by itself as a switch, or with a following value). |
| /N | Numeric | The value of the argument must be a number. |
| /M | Multiple | The argument can accept multiple values (e.g. a list of files). |
| /R | Raw | The argument accepts a "raw" value. For these arguments, the rest of the command line following the argument name is taken as the value.  <br />Arguments of this type are the only ones that do not require quotes around values which contain spaces. |

See the [Internal Command Arguments](/Manual/customize/creating_your_own_buttons/internal_command_arguments.md) page for a full description of the various argument types.
'''
# print(ts.translate_text(q_text, translator='google', from_language='en', to_language='zh'))

# %% [markdown]
# ## g4f

# %%
import g4f
import nest_asyncio
nest_asyncio.apply()

g4f.debug.logging = True

response = g4f.ChatCompletion.create(
    model=g4f.models.gpt_4,
    provider=g4f.Provider.Bing,
    messages=[{"role": "user", "content": '''以简洁易懂的风格将以下英文翻译为中文，保留 Markdown 格式：'''+q_text}]
)

print(response)

# %%
response = g4f.ChatCompletion.create(
    model=g4f.models.gpt_4,
    provider=g4f.Provider.Bing,
    messages=[{"role": "user", "content": f'''According to the terminology table, translate the English text into Chinese:
Terminology:
English | Chinese
--- | ---
Lister | 文件窗口
File display | 文件列表
Find-as-you-type | 即时查找

English text: {q_text}
Chinese:'''}]
)

print(response)
